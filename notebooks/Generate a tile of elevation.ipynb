# %%
from sentinel_tiles import sentinel_tiles
from NASADEM import NASADEM
# Out:
# [2025-12-19 11:10:19 INFO] You're now authenticated with NASA Earthdata Login

# %%
tile = sentinel_tiles.grid("11SPS")
tile
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
elevation_km = NASADEM.elevation_km(geometry=tile)
elevation_km
# Out:
# [2025-12-19 11:10:23 INFO] acquiring NASADEM tile: n32w115
# [2025-12-19 11:10:25 INFO] Granules found: 1
# [2025-12-19 11:10:28 INFO]  Getting 1 granules, approx download size: 0.01 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-12-19 11:10:33 INFO] downloaded NASADEM tile: /Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N32W115.zip
# [2025-12-19 11:10:33 INFO] loading elevation: zip:///Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N32W115.zip!/n32w115.hgt
# [2025-12-19 11:10:33 INFO] acquiring NASADEM tile: n32w116
# [2025-12-19 11:10:34 INFO] Granules found: 1
# [2025-12-19 11:10:38 INFO]  Getting 1 granules, approx download size: 0.01 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-12-19 11:10:40 INFO] downloaded NASADEM tile: /Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N32W116.zip
# [2025-12-19 11:10:40 INFO] loading elevation: zip:///Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N32W116.zip!/n32w116.hgt
# [2025-12-19 11:10:40 INFO] acquiring NASADEM tile: n33w115
# [2025-12-19 11:10:42 INFO] Granules found: 1
# [2025-12-19 11:10:45 INFO]  Getting 1 granules, approx download size: 0.01 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-12-19 11:10:47 INFO] downloaded NASADEM tile: /Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N33W115.zip
# [2025-12-19 11:10:47 INFO] loading elevation: zip:///Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N33W115.zip!/n33w115.hgt
# [2025-12-19 11:10:47 INFO] acquiring NASADEM tile: n33w116
# [2025-12-19 11:10:49 INFO] Granules found: 1
# [2025-12-19 11:10:52 INFO]  Getting 1 granules, approx download size: 0.01 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-12-19 11:10:54 INFO] downloaded NASADEM tile: /Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N33W116.zip
# [2025-12-19 11:10:54 INFO] loading elevation: zip:///Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N33W116.zip!/n33w116.hgt
